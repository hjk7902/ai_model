# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape

# %%
class DCGAN:
	@staticmethod
	def build_generator(dim, depth, channels=1, inputDim=100, outputDim=512):
		# initialize the model along with the input shape to be
		# "channels last" and the channels dimension itself
		model = Sequential()
		inputShape = (dim, dim, depth)
		chanDim = -1
        
		# first set of FC => RELU => BN layers
		model.add(Dense(input_dim=inputDim, units=outputDim))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		# second set of FC => RELU => BN layers, this time preparing
		# the number of FC nodes to be reshaped into a volume
		model.add(Dense(dim * dim * depth))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
        
        # reshape the output of the previous layer set, upsample +
		# apply a transposed convolution, RELU, and BN
		model.add(Reshape(inputShape))
		model.add(Conv2DTranspose(32, (5, 5), strides=(2, 2),
			padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
        
		# apply another upsample and transposed convolution, but
		# this time output the TANH activation
		model.add(Conv2DTranspose(channels, (5, 5), strides=(2, 2),
			padding="same"))
		model.add(Activation("tanh"))
		# return the generator model
		return model
    
	@staticmethod
	def build_discriminator(width, height, depth, alpha=0.2):
		# initialize the model along with the input shape to be
		# "channels last"
		model = Sequential()
		inputShape = (height, width, depth)
		# first set of CONV => RELU layers
		model.add(Conv2D(32, (5, 5), padding="same", strides=(2, 2),
			input_shape=inputShape))
		model.add(LeakyReLU(alpha=alpha))
		# second set of CONV => RELU layers
		model.add(Conv2D(64, (5, 5), padding="same", strides=(2, 2)))
		model.add(LeakyReLU(alpha=alpha))
		# first (and only) set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(512))
		model.add(LeakyReLU(alpha=alpha))
		# sigmoid layer outputting a single value
		model.add(Dense(1))
		model.add(Activation("sigmoid"))
		# return the discriminator model
		return model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import fashion_mnist
from sklearn.utils import shuffle
from imutils import build_montages
import numpy as np
import argparse
import cv2
import os

# %%
NUM_EPOCHS = 50
BATCH_SIZE = 128
INIT_LR = 0.0001

# %%
print("[INFO] loading MNIST dataset...")
((trainX, _), (testX, _)) = fashion_mnist.load_data()
trainImages = np.concatenate([trainX, testX])
# add in an extra dimension for the channel and scale the images
# into the range [-1, 1] (which is the range of the tanh
# function)
trainImages = np.expand_dims(trainImages, axis=-1)
trainImages = (trainImages.astype("float") - 127.5) / 127.5
# Out:
# [INFO] loading MNIST dataset...

# %%
# build the generator
print("[INFO] building generator...")
gen = DCGAN.build_generator(7, 64, channels=1)
# build the discriminator
print("[INFO] building discriminator...")
disc = DCGAN.build_discriminator(28, 28, 1)
discOpt = Adam(learning_rate=INIT_LR, beta_1=0.5, decay=INIT_LR / NUM_EPOCHS)
disc.compile(loss="binary_crossentropy", optimizer=discOpt)
# Out:
# [INFO] building generator...
# [INFO] building discriminator...

# %%
# build the adversarial model by first setting the discriminator to
# *not* be trainable, then combine the generator and discriminator
# together
print("[INFO] building GAN...")
disc.trainable = False
ganInput = Input(shape=(100,))
ganOutput = disc(gen(ganInput))
gan = Model(ganInput, ganOutput)
# compile the GAN
ganOpt = Adam(learning_rate=INIT_LR, beta_1=0.5, decay=INIT_LR / NUM_EPOCHS)
gan.compile(loss="binary_crossentropy", optimizer=discOpt)
# Out:
# [INFO] building GAN...

# %%
# randomly generate some benchmark noise so we can consistently
# visualize how the generative modeling is learning
print("[INFO] starting training...")
benchmarkNoise = np.random.uniform(-1, 1, size=(256, 100))
# loop over the epochs
for epoch in range(0, NUM_EPOCHS):
	# show epoch information and compute the number of batches per
	# epoch
	print("[INFO] starting epoch {} of {}...".format(epoch + 1,
		NUM_EPOCHS))
	batchesPerEpoch = int(trainImages.shape[0] / BATCH_SIZE)
	# loop over the batches
	for i in range(0, batchesPerEpoch):
		# initialize an (empty) output path
		p = None
		# select the next batch of images, then randomly generate
		# noise for the generator to predict on
		imageBatch = trainImages[i * BATCH_SIZE:(i + 1) * BATCH_SIZE]
		noise = np.random.uniform(-1, 1, size=(BATCH_SIZE, 100))
        
		# generate images using the noise + generator model
		genImages = gen.predict(noise, verbose=0)
		# concatenate the *actual* images and the *generated* images,
		# construct class labels for the discriminator, and shuffle
		# the data
		X = np.concatenate((imageBatch, genImages))
		y = ([1] * BATCH_SIZE) + ([0] * BATCH_SIZE)
		y = np.reshape(y, (-1,))
		(X, y) = shuffle(X, y)
		# train the discriminator on the data
		discLoss = disc.train_on_batch(X, y)
        
		# let's now train our generator via the adversarial model by
		# (1) generating random noise and (2) training the generator
		# with the discriminator weights frozen
		noise = np.random.uniform(-1, 1, (BATCH_SIZE, 100))
		fakeLabels = [1] * BATCH_SIZE
		fakeLabels = np.reshape(fakeLabels, (-1,))
		ganLoss = gan.train_on_batch(noise, fakeLabels)
        
		# check to see if this is the end of an epoch, and if so,
		# initialize the output path
		if i == batchesPerEpoch - 1:
			p = ["output", "epoch_{}_output.png".format(
				str(epoch + 1).zfill(4))]
		# otherwise, check to see if we should visualize the current
		# batch for the epoch
		else:
			# create more visualizations early in the training
			# process
			if epoch < 10 and i % 25 == 0:
				p = ["output", "epoch_{}_step_{}.png".format(
					str(epoch + 1).zfill(4), str(i).zfill(5))]
			# visualizations later in the training process are less
			# interesting
			elif epoch >= 10 and i % 100 == 0:
				p = ["output", "epoch_{}_step_{}.png".format(
					str(epoch + 1).zfill(4), str(i).zfill(5))]
                
		# check to see if we should visualize the output of the
		# generator model on our benchmark data
		if p is not None:
			# show loss information
			print("[INFO] Step {}_{}: discriminator_loss={:.6f}, "
				"adversarial_loss={:.6f}".format(epoch + 1, i,
					discLoss, ganLoss))
			# make predictions on the benchmark noise, scale it back
			# to the range [0, 255], and generate the montage
			images = gen.predict(benchmarkNoise)
			images = ((images * 127.5) + 127.5).astype("uint8")
			images = np.repeat(images, 3, axis=-1)
			vis = build_montages(images, (28, 28), (16, 16))[0]
			# write the visualization to disk
			p = os.path.sep.join(p)
			cv2.imwrite(p, vis)
# Out:
# [INFO] starting training...
# [INFO] starting epoch 1 of 50...
# [INFO] Step 1_0: discriminator_loss=0.677924, adversarial_loss=0.653065
# [INFO] Step 1_25: discriminator_loss=0.297281, adversarial_loss=0.117662
# [INFO] Step 1_50: discriminator_loss=0.010984, adversarial_loss=0.025659
# [INFO] Step 1_75: discriminator_loss=0.001444, adversarial_loss=0.006262
# [INFO] Step 1_100: discriminator_loss=0.000743, adversarial_loss=0.003037
# [INFO] Step 1_125: discriminator_loss=0.000535, adversarial_loss=0.002121
# [INFO] Step 1_150: discriminator_loss=0.000618, adversarial_loss=0.001425
# [INFO] Step 1_175: discriminator_loss=0.000734, adversarial_loss=0.001416
# [INFO] Step 1_200: discriminator_loss=0.005991, adversarial_loss=0.002035
# [INFO] Step 1_225: discriminator_loss=0.393411, adversarial_loss=2.105429
# [INFO] Step 1_250: discriminator_loss=0.251844, adversarial_loss=1.280695
# [INFO] Step 1_275: discriminator_loss=0.196350, adversarial_loss=0.321752
# [INFO] Step 1_300: discriminator_loss=0.293868, adversarial_loss=0.824549
# [INFO] Step 1_325: discriminator_loss=0.277326, adversarial_loss=1.341395
# [INFO] Step 1_350: discriminator_loss=0.262498, adversarial_loss=1.172961
# [INFO] Step 1_375: discriminator_loss=0.315500, adversarial_loss=1.462855
# [INFO] Step 1_400: discriminator_loss=0.313812, adversarial_loss=1.208248
# [INFO] Step 1_425: discriminator_loss=0.447230, adversarial_loss=1.852338
# [INFO] Step 1_450: discriminator_loss=0.426022, adversarial_loss=1.185397
# [INFO] Step 1_475: discriminator_loss=0.395074, adversarial_loss=1.480162
# [INFO] Step 1_500: discriminator_loss=0.430712, adversarial_loss=1.076533
# [INFO] Step 1_525: discriminator_loss=0.459859, adversarial_loss=1.077771
# [INFO] Step 1_545: discriminator_loss=0.434489, adversarial_loss=1.226726
# [INFO] starting epoch 2 of 50...
# [INFO] Step 2_0: discriminator_loss=0.452800, adversarial_loss=1.568249
# [INFO] Step 2_25: discriminator_loss=0.496261, adversarial_loss=0.740415
# [INFO] Step 2_50: discriminator_loss=0.479084, adversarial_loss=1.363044
# [INFO] Step 2_75: discriminator_loss=0.483112, adversarial_loss=1.886235
# [INFO] Step 2_100: discriminator_loss=0.469949, adversarial_loss=1.072658
# [INFO] Step 2_125: discriminator_loss=0.417862, adversarial_loss=1.316911
# [INFO] Step 2_150: discriminator_loss=0.434352, adversarial_loss=1.229876
# [INFO] Step 2_175: discriminator_loss=0.455667, adversarial_loss=1.537394
# [INFO] Step 2_200: discriminator_loss=0.444476, adversarial_loss=1.038821
# [INFO] Step 2_225: discriminator_loss=0.486718, adversarial_loss=0.838684
# [INFO] Step 2_250: discriminator_loss=0.586625, adversarial_loss=1.909722
# [INFO] Step 2_275: discriminator_loss=0.492379, adversarial_loss=0.674591
# [INFO] Step 2_300: discriminator_loss=0.479001, adversarial_loss=0.876764
# [INFO] Step 2_325: discriminator_loss=0.616923, adversarial_loss=1.935238
# [INFO] Step 2_350: discriminator_loss=0.442819, adversarial_loss=1.388448
# [INFO] Step 2_375: discriminator_loss=0.479788, adversarial_loss=0.954081
# [INFO] Step 2_400: discriminator_loss=0.468592, adversarial_loss=1.068784
# [INFO] Step 2_425: discriminator_loss=0.444887, adversarial_loss=1.377452
# [INFO] Step 2_450: discriminator_loss=0.441988, adversarial_loss=1.103998
# [INFO] Step 2_475: discriminator_loss=0.437597, adversarial_loss=1.259465
# [INFO] Step 2_500: discriminator_loss=0.469627, adversarial_loss=1.144478
# [INFO] Step 2_525: discriminator_loss=0.491440, adversarial_loss=1.048162
# [INFO] Step 2_545: discriminator_loss=0.457039, adversarial_loss=1.259151
# [INFO] starting epoch 3 of 50...
# [INFO] Step 3_0: discriminator_loss=0.497690, adversarial_loss=1.248364
# [INFO] Step 3_25: discriminator_loss=0.475698, adversarial_loss=0.925356
# [INFO] Step 3_50: discriminator_loss=0.454912, adversarial_loss=1.162533
# [INFO] Step 3_75: discriminator_loss=0.601615, adversarial_loss=2.111747
# [INFO] Step 3_100: discriminator_loss=0.482592, adversarial_loss=0.911707
# [INFO] Step 3_125: discriminator_loss=0.530878, adversarial_loss=1.865143
# [INFO] Step 3_150: discriminator_loss=0.481472, adversarial_loss=1.295418
# [INFO] Step 3_175: discriminator_loss=0.468573, adversarial_loss=1.198013
# [INFO] Step 3_200: discriminator_loss=0.515456, adversarial_loss=0.870647
# [INFO] Step 3_225: discriminator_loss=0.497110, adversarial_loss=1.808726
# [INFO] Step 3_250: discriminator_loss=0.551286, adversarial_loss=1.780553
# [INFO] Step 3_275: discriminator_loss=0.523704, adversarial_loss=0.864116
# [INFO] Step 3_300: discriminator_loss=0.508483, adversarial_loss=1.368088
# [INFO] Step 3_325: discriminator_loss=0.505677, adversarial_loss=1.664913
# [INFO] Step 3_350: discriminator_loss=0.491861, adversarial_loss=1.464929
# [INFO] Step 3_375: discriminator_loss=0.474512, adversarial_loss=1.583068
# [INFO] Step 3_400: discriminator_loss=0.529281, adversarial_loss=1.160020
# [INFO] Step 3_425: discriminator_loss=0.493910, adversarial_loss=1.289621
# [INFO] Step 3_450: discriminator_loss=0.518222, adversarial_loss=1.358361
# [INFO] Step 3_475: discriminator_loss=0.496796, adversarial_loss=1.400286
# [INFO] Step 3_500: discriminator_loss=0.486947, adversarial_loss=1.037379
# [INFO] Step 3_525: discriminator_loss=0.599213, adversarial_loss=0.901663
# [INFO] Step 3_545: discriminator_loss=0.505001, adversarial_loss=0.904710
# [INFO] starting epoch 4 of 50...
# [INFO] Step 4_0: discriminator_loss=0.540786, adversarial_loss=1.497199
# [INFO] Step 4_25: discriminator_loss=0.527587, adversarial_loss=1.163656
# [INFO] Step 4_50: discriminator_loss=0.499792, adversarial_loss=1.094246
# [INFO] Step 4_75: discriminator_loss=0.518133, adversarial_loss=1.525217
# [INFO] Step 4_100: discriminator_loss=0.502675, adversarial_loss=0.984349
# [INFO] Step 4_125: discriminator_loss=0.540626, adversarial_loss=1.511616
# [INFO] Step 4_150: discriminator_loss=0.555725, adversarial_loss=1.216092
# [INFO] Step 4_175: discriminator_loss=0.541552, adversarial_loss=1.351681
# [INFO] Step 4_200: discriminator_loss=0.511001, adversarial_loss=0.862223
# [INFO] Step 4_225: discriminator_loss=0.496024, adversarial_loss=1.014135
# [INFO] Step 4_250: discriminator_loss=0.544649, adversarial_loss=1.087107
# [INFO] Step 4_275: discriminator_loss=0.569403, adversarial_loss=0.919406
# [INFO] Step 4_300: discriminator_loss=0.541769, adversarial_loss=0.805715
# [INFO] Step 4_325: discriminator_loss=0.552665, adversarial_loss=0.842202
# [INFO] Step 4_350: discriminator_loss=0.516481, adversarial_loss=1.236943
# [INFO] Step 4_375: discriminator_loss=0.506347, adversarial_loss=1.372944
# [INFO] Step 4_400: discriminator_loss=0.585335, adversarial_loss=1.008375
# [INFO] Step 4_425: discriminator_loss=0.585887, adversarial_loss=1.205846
# [INFO] Step 4_450: discriminator_loss=0.534356, adversarial_loss=1.134831
# [INFO] Step 4_475: discriminator_loss=0.551454, adversarial_loss=1.342272
# [INFO] Step 4_500: discriminator_loss=0.541108, adversarial_loss=1.154803
# [INFO] Step 4_525: discriminator_loss=0.572435, adversarial_loss=0.870432
# [INFO] Step 4_545: discriminator_loss=0.538820, adversarial_loss=0.840066
# [INFO] starting epoch 5 of 50...
# [INFO] Step 5_0: discriminator_loss=0.534567, adversarial_loss=1.232669
# [INFO] Step 5_25: discriminator_loss=0.567190, adversarial_loss=1.057797
# [INFO] Step 5_50: discriminator_loss=0.560789, adversarial_loss=0.839273
# [INFO] Step 5_75: discriminator_loss=0.514218, adversarial_loss=1.173475
# [INFO] Step 5_100: discriminator_loss=0.517723, adversarial_loss=1.101706
# [INFO] Step 5_125: discriminator_loss=0.555065, adversarial_loss=1.387585
# [INFO] Step 5_150: discriminator_loss=0.585664, adversarial_loss=0.935553
# [INFO] Step 5_175: discriminator_loss=0.572608, adversarial_loss=0.813083
# [INFO] Step 5_200: discriminator_loss=0.537223, adversarial_loss=0.866582
# [INFO] Step 5_225: discriminator_loss=0.557475, adversarial_loss=1.110396
# [INFO] Step 5_250: discriminator_loss=0.573363, adversarial_loss=0.938442
# [INFO] Step 5_275: discriminator_loss=0.593186, adversarial_loss=0.964522
# [INFO] Step 5_300: discriminator_loss=0.546628, adversarial_loss=0.918173
# [INFO] Step 5_325: discriminator_loss=0.569250, adversarial_loss=0.989439
# [INFO] Step 5_350: discriminator_loss=0.542505, adversarial_loss=1.127812
# [INFO] Step 5_375: discriminator_loss=0.525021, adversarial_loss=1.288627
# [INFO] Step 5_400: discriminator_loss=0.592617, adversarial_loss=0.929454
# [INFO] Step 5_425: discriminator_loss=0.562356, adversarial_loss=1.025241
# [INFO] Step 5_450: discriminator_loss=0.584466, adversarial_loss=0.746879
# [INFO] Step 5_475: discriminator_loss=0.541210, adversarial_loss=1.039078
# [INFO] Step 5_500: discriminator_loss=0.550642, adversarial_loss=1.048534
# [INFO] Step 5_525: discriminator_loss=0.573782, adversarial_loss=0.975919
# [INFO] Step 5_545: discriminator_loss=0.543747, adversarial_loss=1.083851
# [INFO] starting epoch 6 of 50...
# [INFO] Step 6_0: discriminator_loss=0.549744, adversarial_loss=0.778370
# [INFO] Step 6_25: discriminator_loss=0.562357, adversarial_loss=0.706670
# [INFO] Step 6_50: discriminator_loss=0.585162, adversarial_loss=0.920459
# [INFO] Step 6_75: discriminator_loss=0.560714, adversarial_loss=1.288753
# [INFO] Step 6_100: discriminator_loss=0.538416, adversarial_loss=1.081023
# [INFO] Step 6_125: discriminator_loss=0.561535, adversarial_loss=1.088322
# [INFO] Step 6_150: discriminator_loss=0.645020, adversarial_loss=0.770923
# [INFO] Step 6_175: discriminator_loss=0.587822, adversarial_loss=0.854347
# [INFO] Step 6_200: discriminator_loss=0.600478, adversarial_loss=0.682919
# [INFO] Step 6_225: discriminator_loss=0.612586, adversarial_loss=1.246619
# [INFO] Step 6_250: discriminator_loss=0.583057, adversarial_loss=0.733355
# [INFO] Step 6_275: discriminator_loss=0.574883, adversarial_loss=0.885091
# [INFO] Step 6_300: discriminator_loss=0.567664, adversarial_loss=0.825279
# [INFO] Step 6_325: discriminator_loss=0.568422, adversarial_loss=0.755194
# [INFO] Step 6_350: discriminator_loss=0.594182, adversarial_loss=1.331548
# [INFO] Step 6_375: discriminator_loss=0.542274, adversarial_loss=0.755451
# [INFO] Step 6_400: discriminator_loss=0.576219, adversarial_loss=1.030027
# [INFO] Step 6_425: discriminator_loss=0.593517, adversarial_loss=1.017683
# [INFO] Step 6_450: discriminator_loss=0.591547, adversarial_loss=1.048662
# [INFO] Step 6_475: discriminator_loss=0.579636, adversarial_loss=1.003749
# [INFO] Step 6_500: discriminator_loss=0.568134, adversarial_loss=1.113826
# [INFO] Step 6_525: discriminator_loss=0.586812, adversarial_loss=0.875798
# [INFO] Step 6_545: discriminator_loss=0.554757, adversarial_loss=0.860307
# [INFO] starting epoch 7 of 50...
# [INFO] Step 7_0: discriminator_loss=0.586488, adversarial_loss=1.054938
# [INFO] Step 7_25: discriminator_loss=0.574412, adversarial_loss=0.944217
# [INFO] Step 7_50: discriminator_loss=0.643736, adversarial_loss=1.397801
# [INFO] Step 7_75: discriminator_loss=0.557141, adversarial_loss=0.932394
# [INFO] Step 7_100: discriminator_loss=0.547879, adversarial_loss=1.233546
# [INFO] Step 7_125: discriminator_loss=0.587129, adversarial_loss=0.917129
# [INFO] Step 7_150: discriminator_loss=0.612023, adversarial_loss=0.925656
# [INFO] Step 7_175: discriminator_loss=0.613580, adversarial_loss=0.759564
# [INFO] Step 7_200: discriminator_loss=0.608182, adversarial_loss=0.574050
# [INFO] Step 7_225: discriminator_loss=0.587631, adversarial_loss=0.743134
# [INFO] Step 7_250: discriminator_loss=0.577137, adversarial_loss=0.844425
# [INFO] Step 7_275: discriminator_loss=0.591951, adversarial_loss=0.728315
# [INFO] Step 7_300: discriminator_loss=0.575595, adversarial_loss=0.840219
# [INFO] Step 7_325: discriminator_loss=0.580608, adversarial_loss=0.856691
# [INFO] Step 7_350: discriminator_loss=0.580105, adversarial_loss=1.235068
# [INFO] Step 7_375: discriminator_loss=0.558360, adversarial_loss=0.805575
# [INFO] Step 7_400: discriminator_loss=0.619395, adversarial_loss=0.647182
# [INFO] Step 7_425: discriminator_loss=0.591597, adversarial_loss=0.990295
# [INFO] Step 7_450: discriminator_loss=0.594582, adversarial_loss=0.811529
# [INFO] Step 7_475: discriminator_loss=0.581320, adversarial_loss=0.799784
# [INFO] Step 7_500: discriminator_loss=0.576396, adversarial_loss=0.988617
# [INFO] Step 7_525: discriminator_loss=0.615182, adversarial_loss=0.836927
# [INFO] Step 7_545: discriminator_loss=0.565310, adversarial_loss=0.813737
# [INFO] starting epoch 8 of 50...
# [INFO] Step 8_0: discriminator_loss=0.585666, adversarial_loss=1.036043
# [INFO] Step 8_25: discriminator_loss=0.573164, adversarial_loss=0.879259
# [INFO] Step 8_50: discriminator_loss=0.625497, adversarial_loss=1.239008
# [INFO] Step 8_75: discriminator_loss=0.553887, adversarial_loss=0.892575
# [INFO] Step 8_100: discriminator_loss=0.552068, adversarial_loss=1.133755
# [INFO] Step 8_125: discriminator_loss=0.593145, adversarial_loss=1.081312
# [INFO] Step 8_150: discriminator_loss=0.616864, adversarial_loss=0.954700
# [INFO] Step 8_175: discriminator_loss=0.612885, adversarial_loss=0.561021
# [INFO] Step 8_200: discriminator_loss=0.638654, adversarial_loss=0.667933
# [INFO] Step 8_225: discriminator_loss=0.594729, adversarial_loss=0.793209
# [INFO] Step 8_250: discriminator_loss=0.599625, adversarial_loss=0.795065
# [INFO] Step 8_275: discriminator_loss=0.666940, adversarial_loss=0.630115
# [INFO] Step 8_300: discriminator_loss=0.573343, adversarial_loss=0.872002
# [INFO] Step 8_325: discriminator_loss=0.596859, adversarial_loss=0.851565
# [INFO] Step 8_350: discriminator_loss=0.582559, adversarial_loss=1.072893
# [INFO] Step 8_375: discriminator_loss=0.569512, adversarial_loss=1.044711
# [INFO] Step 8_400: discriminator_loss=0.607202, adversarial_loss=0.915326
# [INFO] Step 8_425: discriminator_loss=0.597291, adversarial_loss=1.065165
# [INFO] Step 8_450: discriminator_loss=0.595635, adversarial_loss=0.898985
# [INFO] Step 8_475: discriminator_loss=0.572820, adversarial_loss=0.779251
# [INFO] Step 8_500: discriminator_loss=0.593230, adversarial_loss=0.981871
# [INFO] Step 8_525: discriminator_loss=0.589380, adversarial_loss=0.767173
# [INFO] Step 8_545: discriminator_loss=0.580639, adversarial_loss=0.897289
# [INFO] starting epoch 9 of 50...
# [INFO] Step 9_0: discriminator_loss=0.593652, adversarial_loss=0.911748
# [INFO] Step 9_25: discriminator_loss=0.572617, adversarial_loss=0.870659
# [INFO] Step 9_50: discriminator_loss=0.609067, adversarial_loss=1.130854
# [INFO] Step 9_75: discriminator_loss=0.574852, adversarial_loss=1.185920
# [INFO] Step 9_100: discriminator_loss=0.560453, adversarial_loss=1.202146
# [INFO] Step 9_125: discriminator_loss=0.596864, adversarial_loss=0.680778
# [INFO] Step 9_150: discriminator_loss=0.617077, adversarial_loss=0.867865
# [INFO] Step 9_175: discriminator_loss=0.638392, adversarial_loss=0.604552
# [INFO] Step 9_200: discriminator_loss=0.587950, adversarial_loss=0.753685
# [INFO] Step 9_225: discriminator_loss=0.600382, adversarial_loss=0.945839
# [INFO] Step 9_250: discriminator_loss=0.579437, adversarial_loss=0.999908
# [INFO] Step 9_275: discriminator_loss=0.596666, adversarial_loss=0.629323
# [INFO] Step 9_300: discriminator_loss=0.595339, adversarial_loss=0.796452
# [INFO] Step 9_325: discriminator_loss=0.577690, adversarial_loss=0.824636
# [INFO] Step 9_350: discriminator_loss=0.569966, adversarial_loss=1.030326
# [INFO] Step 9_375: discriminator_loss=0.571475, adversarial_loss=0.854512
# [INFO] Step 9_400: discriminator_loss=0.610828, adversarial_loss=0.790396
# [INFO] Step 9_425: discriminator_loss=0.604516, adversarial_loss=0.886087
# [INFO] Step 9_450: discriminator_loss=0.616821, adversarial_loss=0.874523
# [INFO] Step 9_475: discriminator_loss=0.586600, adversarial_loss=0.842121
# [INFO] Step 9_500: discriminator_loss=0.621575, adversarial_loss=1.059953
# [INFO] Step 9_525: discriminator_loss=0.611819, adversarial_loss=0.735085
# [INFO] Step 9_545: discriminator_loss=0.593286, adversarial_loss=0.920640
# [INFO] starting epoch 10 of 50...
# [INFO] Step 10_0: discriminator_loss=0.599176, adversarial_loss=0.881682
# [INFO] Step 10_25: discriminator_loss=0.585412, adversarial_loss=0.796059
# [INFO] Step 10_50: discriminator_loss=0.591869, adversarial_loss=0.968995
# [INFO] Step 10_75: discriminator_loss=0.597478, adversarial_loss=1.193049
# [INFO] Step 10_100: discriminator_loss=0.560857, adversarial_loss=0.944787
# [INFO] Step 10_125: discriminator_loss=0.647508, adversarial_loss=0.646717
# [INFO] Step 10_150: discriminator_loss=0.610073, adversarial_loss=0.936121
# [INFO] Step 10_175: discriminator_loss=0.632864, adversarial_loss=0.800817
# [INFO] Step 10_200: discriminator_loss=0.588954, adversarial_loss=0.720946
# [INFO] Step 10_225: discriminator_loss=0.612350, adversarial_loss=0.776284
# [INFO] Step 10_250: discriminator_loss=0.633370, adversarial_loss=1.032824
# [INFO] Step 10_275: discriminator_loss=0.612349, adversarial_loss=0.735000
# [INFO] Step 10_300: discriminator_loss=0.604622, adversarial_loss=1.038321
# [INFO] Step 10_325: discriminator_loss=0.609841, adversarial_loss=0.815829
# [INFO] Step 10_350: discriminator_loss=0.591509, adversarial_loss=1.154749
# [INFO] Step 10_375: discriminator_loss=0.594396, adversarial_loss=1.105809
# [INFO] Step 10_400: discriminator_loss=0.602663, adversarial_loss=0.862834
# [INFO] Step 10_425: discriminator_loss=0.603169, adversarial_loss=0.819427
# [INFO] Step 10_450: discriminator_loss=0.609713, adversarial_loss=0.929564
# [INFO] Step 10_475: discriminator_loss=0.594033, adversarial_loss=0.619670
# [INFO] Step 10_500: discriminator_loss=0.614398, adversarial_loss=0.859107
# [INFO] Step 10_525: discriminator_loss=0.602576, adversarial_loss=0.946082
# [INFO] Step 10_545: discriminator_loss=0.590531, adversarial_loss=0.740796
# [INFO] starting epoch 11 of 50...
# [INFO] Step 11_0: discriminator_loss=0.605493, adversarial_loss=0.981298
# [INFO] Step 11_100: discriminator_loss=0.562819, adversarial_loss=0.971048
# [INFO] Step 11_200: discriminator_loss=0.637164, adversarial_loss=0.531356
# [INFO] Step 11_300: discriminator_loss=0.592088, adversarial_loss=0.886331
# [INFO] Step 11_400: discriminator_loss=0.620859, adversarial_loss=0.751043
# [INFO] Step 11_500: discriminator_loss=0.607801, adversarial_loss=0.986539
# [INFO] Step 11_545: discriminator_loss=0.566808, adversarial_loss=0.788732
# [INFO] starting epoch 12 of 50...
# [INFO] Step 12_0: discriminator_loss=0.592500, adversarial_loss=1.055879
# [INFO] Step 12_100: discriminator_loss=0.590472, adversarial_loss=0.967614
# [INFO] Step 12_200: discriminator_loss=0.595644, adversarial_loss=0.737620
# [INFO] Step 12_300: discriminator_loss=0.625962, adversarial_loss=0.688291
# [INFO] Step 12_400: discriminator_loss=0.631898, adversarial_loss=0.860147
# [INFO] Step 12_500: discriminator_loss=0.599448, adversarial_loss=0.783429
# [INFO] Step 12_545: discriminator_loss=0.592005, adversarial_loss=0.828323
# [INFO] starting epoch 13 of 50...
# [INFO] Step 13_0: discriminator_loss=0.611490, adversarial_loss=0.883039
# [INFO] Step 13_100: discriminator_loss=0.648229, adversarial_loss=1.502079
# [INFO] Step 13_200: discriminator_loss=0.633377, adversarial_loss=0.534366
# [INFO] Step 13_300: discriminator_loss=0.586765, adversarial_loss=0.846434
# [INFO] Step 13_400: discriminator_loss=0.610832, adversarial_loss=0.809368
# [INFO] Step 13_500: discriminator_loss=0.615574, adversarial_loss=0.634772
# [INFO] Step 13_545: discriminator_loss=0.592325, adversarial_loss=0.776546
# [INFO] starting epoch 14 of 50...
# [INFO] Step 14_0: discriminator_loss=0.597074, adversarial_loss=1.012082
# [INFO] Step 14_100: discriminator_loss=0.635609, adversarial_loss=1.263503
# [INFO] Step 14_200: discriminator_loss=0.596312, adversarial_loss=0.636675
# [INFO] Step 14_300: discriminator_loss=0.600147, adversarial_loss=0.969436
# [INFO] Step 14_400: discriminator_loss=0.633754, adversarial_loss=0.813532
# [INFO] Step 14_500: discriminator_loss=0.604048, adversarial_loss=0.786442
# [INFO] Step 14_545: discriminator_loss=0.624754, adversarial_loss=0.981724
# [INFO] starting epoch 15 of 50...
# [INFO] Step 15_0: discriminator_loss=0.616096, adversarial_loss=0.845372
# [INFO] Step 15_100: discriminator_loss=0.590819, adversarial_loss=1.178605
# [INFO] Step 15_200: discriminator_loss=0.587393, adversarial_loss=0.791757
# [INFO] Step 15_300: discriminator_loss=0.607662, adversarial_loss=0.843184
# [INFO] Step 15_400: discriminator_loss=0.626282, adversarial_loss=0.793897
# [INFO] Step 15_500: discriminator_loss=0.617803, adversarial_loss=1.045187
# [INFO] Step 15_545: discriminator_loss=0.601393, adversarial_loss=0.963360
# [INFO] starting epoch 16 of 50...
# [INFO] Step 16_0: discriminator_loss=0.611474, adversarial_loss=0.799087
# [INFO] Step 16_100: discriminator_loss=0.608047, adversarial_loss=1.243529
# [INFO] Step 16_200: discriminator_loss=0.593182, adversarial_loss=0.787917
# [INFO] Step 16_300: discriminator_loss=0.613347, adversarial_loss=1.084445
# [INFO] Step 16_400: discriminator_loss=0.616621, adversarial_loss=0.788527
# [INFO] Step 16_500: discriminator_loss=0.633788, adversarial_loss=0.910107
# [INFO] Step 16_545: discriminator_loss=0.596520, adversarial_loss=0.717243
# [INFO] starting epoch 17 of 50...
# [INFO] Step 17_0: discriminator_loss=0.611748, adversarial_loss=0.980049
# [INFO] Step 17_100: discriminator_loss=0.591847, adversarial_loss=1.121448
# [INFO] Step 17_200: discriminator_loss=0.575875, adversarial_loss=0.939734
# [INFO] Step 17_300: discriminator_loss=0.608890, adversarial_loss=0.701231
# [INFO] Step 17_400: discriminator_loss=0.612646, adversarial_loss=0.808582
# [INFO] Step 17_500: discriminator_loss=0.596122, adversarial_loss=0.764028
# [INFO] Step 17_545: discriminator_loss=0.615903, adversarial_loss=1.118299
# [INFO] starting epoch 18 of 50...
# [INFO] Step 18_0: discriminator_loss=0.600216, adversarial_loss=0.734274
# [INFO] Step 18_100: discriminator_loss=0.589528, adversarial_loss=0.833330
# [INFO] Step 18_200: discriminator_loss=0.613214, adversarial_loss=0.756429
# [INFO] Step 18_300: discriminator_loss=0.599833, adversarial_loss=0.623751
# [INFO] Step 18_400: discriminator_loss=0.616334, adversarial_loss=0.809026
# [INFO] Step 18_500: discriminator_loss=0.649027, adversarial_loss=0.616357
# [INFO] Step 18_545: discriminator_loss=0.622198, adversarial_loss=0.699668
# [INFO] starting epoch 19 of 50...
# [INFO] Step 19_0: discriminator_loss=0.605787, adversarial_loss=1.031029
# [INFO] Step 19_100: discriminator_loss=0.584396, adversarial_loss=0.823352
# [INFO] Step 19_200: discriminator_loss=0.577319, adversarial_loss=0.938941
# [INFO] Step 19_300: discriminator_loss=0.613086, adversarial_loss=1.097258
# [INFO] Step 19_400: discriminator_loss=0.633198, adversarial_loss=0.783432
# [INFO] Step 19_500: discriminator_loss=0.594987, adversarial_loss=0.882017
# [INFO] Step 19_545: discriminator_loss=0.591685, adversarial_loss=0.700296
# [INFO] starting epoch 20 of 50...
# [INFO] Step 20_0: discriminator_loss=0.605567, adversarial_loss=1.028917
# [INFO] Step 20_100: discriminator_loss=0.639432, adversarial_loss=1.412044
# [INFO] Step 20_200: discriminator_loss=0.620953, adversarial_loss=0.636695
# [INFO] Step 20_300: discriminator_loss=0.585402, adversarial_loss=0.832243
# [INFO] Step 20_400: discriminator_loss=0.647955, adversarial_loss=0.615311
# [INFO] Step 20_500: discriminator_loss=0.600794, adversarial_loss=0.722371
# [INFO] Step 20_545: discriminator_loss=0.593349, adversarial_loss=0.984710
# [INFO] starting epoch 21 of 50...
# [INFO] Step 21_0: discriminator_loss=0.583269, adversarial_loss=0.723393
# [INFO] Step 21_100: discriminator_loss=0.606214, adversarial_loss=1.262158
# [INFO] Step 21_200: discriminator_loss=0.593302, adversarial_loss=0.807463
# [INFO] Step 21_300: discriminator_loss=0.615208, adversarial_loss=1.146944
# [INFO] Step 21_400: discriminator_loss=0.637509, adversarial_loss=0.656643
# [INFO] Step 21_500: discriminator_loss=0.598322, adversarial_loss=0.650054
# [INFO] Step 21_545: discriminator_loss=0.602114, adversarial_loss=0.936955
# [INFO] starting epoch 22 of 50...
# [INFO] Step 22_0: discriminator_loss=0.578527, adversarial_loss=0.868466
# [INFO] Step 22_100: discriminator_loss=0.584518, adversarial_loss=0.948204
# [INFO] Step 22_200: discriminator_loss=0.576908, adversarial_loss=0.933287
# [INFO] Step 22_300: discriminator_loss=0.590809, adversarial_loss=0.890318
# [INFO] Step 22_400: discriminator_loss=0.619535, adversarial_loss=0.599276
# [INFO] Step 22_500: discriminator_loss=0.595458, adversarial_loss=0.806998
# [INFO] Step 22_545: discriminator_loss=0.581973, adversarial_loss=0.913185
# [INFO] starting epoch 23 of 50...
# [INFO] Step 23_0: discriminator_loss=0.598898, adversarial_loss=0.846167
# [INFO] Step 23_100: discriminator_loss=0.573787, adversarial_loss=1.069804
# [INFO] Step 23_200: discriminator_loss=0.578747, adversarial_loss=0.813819
# [INFO] Step 23_300: discriminator_loss=0.583276, adversarial_loss=0.782241
# [INFO] Step 23_400: discriminator_loss=0.623367, adversarial_loss=0.786501
# [INFO] Step 23_500: discriminator_loss=0.608871, adversarial_loss=0.994423
# [INFO] Step 23_545: discriminator_loss=0.622219, adversarial_loss=0.971292
# [INFO] starting epoch 24 of 50...
# [INFO] Step 24_0: discriminator_loss=0.604360, adversarial_loss=0.812053
# [INFO] Step 24_100: discriminator_loss=0.597027, adversarial_loss=1.365095
# [INFO] Step 24_200: discriminator_loss=0.571188, adversarial_loss=0.938385
# [INFO] Step 24_300: discriminator_loss=0.599546, adversarial_loss=0.873887
# [INFO] Step 24_400: discriminator_loss=0.643905, adversarial_loss=0.764921
# [INFO] Step 24_500: discriminator_loss=0.613748, adversarial_loss=0.905916
# [INFO] Step 24_545: discriminator_loss=0.606943, adversarial_loss=1.008243
# [INFO] starting epoch 25 of 50...
# [INFO] Step 25_0: discriminator_loss=0.594090, adversarial_loss=0.741316
# [INFO] Step 25_100: discriminator_loss=0.577712, adversarial_loss=0.959484
# [INFO] Step 25_200: discriminator_loss=0.565499, adversarial_loss=1.023621
# [INFO] Step 25_300: discriminator_loss=0.576311, adversarial_loss=0.826706
# [INFO] Step 25_400: discriminator_loss=0.645218, adversarial_loss=0.955305
# [INFO] Step 25_500: discriminator_loss=0.582257, adversarial_loss=0.911900
# [INFO] Step 25_545: discriminator_loss=0.608346, adversarial_loss=1.050033
# [INFO] starting epoch 26 of 50...
# [INFO] Step 26_0: discriminator_loss=0.592275, adversarial_loss=0.828861
# [INFO] Step 26_100: discriminator_loss=0.547977, adversarial_loss=1.169349
# [INFO] Step 26_200: discriminator_loss=0.564857, adversarial_loss=0.760160
# [INFO] Step 26_300: discriminator_loss=0.590278, adversarial_loss=1.152479
# [INFO] Step 26_400: discriminator_loss=0.635036, adversarial_loss=0.903202
# [INFO] Step 26_500: discriminator_loss=0.580810, adversarial_loss=0.806572
# [INFO] Step 26_545: discriminator_loss=0.606974, adversarial_loss=1.089362
# [INFO] starting epoch 27 of 50...
# [INFO] Step 27_0: discriminator_loss=0.594880, adversarial_loss=0.749302
# [INFO] Step 27_100: discriminator_loss=0.590028, adversarial_loss=1.137389
# [INFO] Step 27_200: discriminator_loss=0.579957, adversarial_loss=0.767422
# [INFO] Step 27_300: discriminator_loss=0.604081, adversarial_loss=0.838300
# [INFO] Step 27_400: discriminator_loss=0.653743, adversarial_loss=0.572769
# [INFO] Step 27_500: discriminator_loss=0.610628, adversarial_loss=0.794361
# [INFO] Step 27_545: discriminator_loss=0.590355, adversarial_loss=0.842200
# [INFO] starting epoch 28 of 50...
# [INFO] Step 28_0: discriminator_loss=0.592320, adversarial_loss=1.083370
# [INFO] Step 28_100: discriminator_loss=0.578999, adversarial_loss=1.029291
# [INFO] Step 28_200: discriminator_loss=0.565386, adversarial_loss=0.894856
# [INFO] Step 28_300: discriminator_loss=0.570896, adversarial_loss=0.753314
# [INFO] Step 28_400: discriminator_loss=0.629884, adversarial_loss=0.754318
# [INFO] Step 28_500: discriminator_loss=0.643076, adversarial_loss=0.659865
# [INFO] Step 28_545: discriminator_loss=0.605278, adversarial_loss=1.015150
# [INFO] starting epoch 29 of 50...
# [INFO] Step 29_0: discriminator_loss=0.591815, adversarial_loss=0.827903
# [INFO] Step 29_100: discriminator_loss=0.611636, adversarial_loss=1.328005
# [INFO] Step 29_200: discriminator_loss=0.580506, adversarial_loss=0.921099
# [INFO] Step 29_300: discriminator_loss=0.591296, adversarial_loss=0.902621
# [INFO] Step 29_400: discriminator_loss=0.617935, adversarial_loss=0.798868
# [INFO] Step 29_500: discriminator_loss=0.596408, adversarial_loss=0.776443
# [INFO] Step 29_545: discriminator_loss=0.598655, adversarial_loss=0.763517
# [INFO] starting epoch 30 of 50...
# [INFO] Step 30_0: discriminator_loss=0.602869, adversarial_loss=1.014657
# [INFO] Step 30_100: discriminator_loss=0.583405, adversarial_loss=1.116352
# [INFO] Step 30_200: discriminator_loss=0.562680, adversarial_loss=0.778116
# [INFO] Step 30_300: discriminator_loss=0.582031, adversarial_loss=0.850911
# [INFO] Step 30_400: discriminator_loss=0.631435, adversarial_loss=0.917985
# [INFO] Step 30_500: discriminator_loss=0.605929, adversarial_loss=0.815874
# [INFO] Step 30_545: discriminator_loss=0.586028, adversarial_loss=0.908837
# [INFO] starting epoch 31 of 50...
# [INFO] Step 31_0: discriminator_loss=0.600334, adversarial_loss=0.925636
# [INFO] Step 31_100: discriminator_loss=0.580422, adversarial_loss=0.939651
# [INFO] Step 31_200: discriminator_loss=0.554577, adversarial_loss=0.987892
# [INFO] Step 31_300: discriminator_loss=0.591455, adversarial_loss=1.020813
# [INFO] Step 31_400: discriminator_loss=0.614924, adversarial_loss=0.702972
# [INFO] Step 31_500: discriminator_loss=0.580368, adversarial_loss=0.815570
# [INFO] Step 31_545: discriminator_loss=0.586837, adversarial_loss=1.042637
# [INFO] starting epoch 32 of 50...
# [INFO] Step 32_0: discriminator_loss=0.586548, adversarial_loss=0.698033
# [INFO] Step 32_100: discriminator_loss=0.581245, adversarial_loss=1.180351
# [INFO] Step 32_200: discriminator_loss=0.607584, adversarial_loss=0.759585
# [INFO] Step 32_300: discriminator_loss=0.588061, adversarial_loss=0.814051
# [INFO] Step 32_400: discriminator_loss=0.631370, adversarial_loss=0.598819
# [INFO] Step 32_500: discriminator_loss=0.607727, adversarial_loss=0.778749
# [INFO] Step 32_545: discriminator_loss=0.582969, adversarial_loss=0.937603
# [INFO] starting epoch 33 of 50...
# [INFO] Step 33_0: discriminator_loss=0.588136, adversarial_loss=0.876562
# [INFO] Step 33_100: discriminator_loss=0.595234, adversarial_loss=0.752246
# [INFO] Step 33_200: discriminator_loss=0.564944, adversarial_loss=0.955652
# [INFO] Step 33_300: discriminator_loss=0.584327, adversarial_loss=0.840906
# [INFO] Step 33_400: discriminator_loss=0.600205, adversarial_loss=0.797872
# [INFO] Step 33_500: discriminator_loss=0.592045, adversarial_loss=0.656608
# [INFO] Step 33_545: discriminator_loss=0.605232, adversarial_loss=1.234604
# [INFO] starting epoch 34 of 50...
# [INFO] Step 34_0: discriminator_loss=0.620644, adversarial_loss=0.571961
# [INFO] Step 34_100: discriminator_loss=0.609444, adversarial_loss=0.764695
# [INFO] Step 34_200: discriminator_loss=0.570004, adversarial_loss=0.929590
# [INFO] Step 34_300: discriminator_loss=0.577685, adversarial_loss=0.887068
# [INFO] Step 34_400: discriminator_loss=0.624053, adversarial_loss=0.676941
# [INFO] Step 34_500: discriminator_loss=0.615240, adversarial_loss=0.695400
# [INFO] Step 34_545: discriminator_loss=0.568865, adversarial_loss=0.911837
# [INFO] starting epoch 35 of 50...
# [INFO] Step 35_0: discriminator_loss=0.579417, adversarial_loss=1.051586
# [INFO] Step 35_100: discriminator_loss=0.585694, adversarial_loss=0.899608
# [INFO] Step 35_200: discriminator_loss=0.591191, adversarial_loss=1.163879
# [INFO] Step 35_300: discriminator_loss=0.607091, adversarial_loss=1.055702
# [INFO] Step 35_400: discriminator_loss=0.608155, adversarial_loss=0.802579
# [INFO] Step 35_500: discriminator_loss=0.618017, adversarial_loss=0.564858
# [INFO] Step 35_545: discriminator_loss=0.577887, adversarial_loss=1.005471
# [INFO] starting epoch 36 of 50...
# [INFO] Step 36_0: discriminator_loss=0.572097, adversarial_loss=0.850482
# [INFO] Step 36_100: discriminator_loss=0.573050, adversarial_loss=1.288305
# [INFO] Step 36_200: discriminator_loss=0.575492, adversarial_loss=1.116888
# [INFO] Step 36_300: discriminator_loss=0.596063, adversarial_loss=0.649085
# [INFO] Step 36_400: discriminator_loss=0.617147, adversarial_loss=0.715067
# [INFO] Step 36_500: discriminator_loss=0.595771, adversarial_loss=0.856641
# [INFO] Step 36_545: discriminator_loss=0.601493, adversarial_loss=1.136156
# [INFO] starting epoch 37 of 50...
# [INFO] Step 37_0: discriminator_loss=0.569399, adversarial_loss=0.772822
# [INFO] Step 37_100: discriminator_loss=0.563735, adversarial_loss=1.053648
# [INFO] Step 37_200: discriminator_loss=0.577381, adversarial_loss=1.048098
# [INFO] Step 37_300: discriminator_loss=0.573369, adversarial_loss=0.788260
# [INFO] Step 37_400: discriminator_loss=0.605353, adversarial_loss=0.837744
# [INFO] Step 37_500: discriminator_loss=0.606288, adversarial_loss=0.708886
# [INFO] Step 37_545: discriminator_loss=0.584224, adversarial_loss=1.112324
# [INFO] starting epoch 38 of 50...
# [INFO] Step 38_0: discriminator_loss=0.586810, adversarial_loss=0.694005
# [INFO] Step 38_100: discriminator_loss=0.580586, adversarial_loss=1.056541
# [INFO] Step 38_200: discriminator_loss=0.577399, adversarial_loss=0.943936
# [INFO] Step 38_300: discriminator_loss=0.589200, adversarial_loss=1.013558
# [INFO] Step 38_400: discriminator_loss=0.629730, adversarial_loss=0.553037
# [INFO] Step 38_500: discriminator_loss=0.608030, adversarial_loss=0.664866
# [INFO] Step 38_545: discriminator_loss=0.583986, adversarial_loss=1.145829
# [INFO] starting epoch 39 of 50...
# [INFO] Step 39_0: discriminator_loss=0.589808, adversarial_loss=0.710767
# [INFO] Step 39_100: discriminator_loss=0.619795, adversarial_loss=1.223324
# [INFO] Step 39_200: discriminator_loss=0.567982, adversarial_loss=1.172667
# [INFO] Step 39_300: discriminator_loss=0.581595, adversarial_loss=0.814006
# [INFO] Step 39_400: discriminator_loss=0.626509, adversarial_loss=0.848172
# [INFO] Step 39_500: discriminator_loss=0.583936, adversarial_loss=0.933369
# [INFO] Step 39_545: discriminator_loss=0.565812, adversarial_loss=1.160597
# [INFO] starting epoch 40 of 50...
# [INFO] Step 40_0: discriminator_loss=0.595308, adversarial_loss=0.841460
# [INFO] Step 40_100: discriminator_loss=0.563227, adversarial_loss=0.740018
# [INFO] Step 40_200: discriminator_loss=0.561489, adversarial_loss=1.033474
# [INFO] Step 40_300: discriminator_loss=0.576912, adversarial_loss=0.990586
# [INFO] Step 40_400: discriminator_loss=0.632197, adversarial_loss=0.692278
# [INFO] Step 40_500: discriminator_loss=0.604369, adversarial_loss=0.695712
# [INFO] Step 40_545: discriminator_loss=0.592075, adversarial_loss=1.120813
# [INFO] starting epoch 41 of 50...
# [INFO] Step 41_0: discriminator_loss=0.585419, adversarial_loss=0.883350
# [INFO] Step 41_100: discriminator_loss=0.610485, adversarial_loss=1.377809
# [INFO] Step 41_200: discriminator_loss=0.558391, adversarial_loss=1.173788
# [INFO] Step 41_300: discriminator_loss=0.575610, adversarial_loss=1.065599
# [INFO] Step 41_400: discriminator_loss=0.643616, adversarial_loss=0.565136
# [INFO] Step 41_500: discriminator_loss=0.640391, adversarial_loss=0.746372
# [INFO] Step 41_545: discriminator_loss=0.565440, adversarial_loss=0.906271
# [INFO] starting epoch 42 of 50...
# [INFO] Step 42_0: discriminator_loss=0.572128, adversarial_loss=0.953805
# [INFO] Step 42_100: discriminator_loss=0.557600, adversarial_loss=0.935094
# [INFO] Step 42_200: discriminator_loss=0.548906, adversarial_loss=1.009539
# [INFO] Step 42_300: discriminator_loss=0.577662, adversarial_loss=1.072839
# [INFO] Step 42_400: discriminator_loss=0.642214, adversarial_loss=0.538387
# [INFO] Step 42_500: discriminator_loss=0.592134, adversarial_loss=0.750162
# [INFO] Step 42_545: discriminator_loss=0.572840, adversarial_loss=0.941139
# [INFO] starting epoch 43 of 50...
# [INFO] Step 43_0: discriminator_loss=0.571088, adversarial_loss=0.919056
# [INFO] Step 43_100: discriminator_loss=0.549758, adversarial_loss=1.199286
# [INFO] Step 43_200: discriminator_loss=0.544593, adversarial_loss=0.912283
# [INFO] Step 43_300: discriminator_loss=0.581324, adversarial_loss=0.852597
# [INFO] Step 43_400: discriminator_loss=0.611029, adversarial_loss=0.837870
# [INFO] Step 43_500: discriminator_loss=0.591684, adversarial_loss=0.767041
# [INFO] Step 43_545: discriminator_loss=0.565309, adversarial_loss=0.827878
# [INFO] starting epoch 44 of 50...
# [INFO] Step 44_0: discriminator_loss=0.587481, adversarial_loss=1.080840
# [INFO] Step 44_100: discriminator_loss=0.557517, adversarial_loss=1.009563
# [INFO] Step 44_200: discriminator_loss=0.559778, adversarial_loss=1.063003
# [INFO] Step 44_300: discriminator_loss=0.547071, adversarial_loss=0.846966
# [INFO] Step 44_400: discriminator_loss=0.591328, adversarial_loss=0.919544
# [INFO] Step 44_500: discriminator_loss=0.571145, adversarial_loss=0.831038
# [INFO] Step 44_545: discriminator_loss=0.555130, adversarial_loss=0.979175
# [INFO] starting epoch 45 of 50...
# [INFO] Step 45_0: discriminator_loss=0.577729, adversarial_loss=1.162831
# [INFO] Step 45_100: discriminator_loss=0.544525, adversarial_loss=0.851371
# [INFO] Step 45_200: discriminator_loss=0.563504, adversarial_loss=0.971365
# [INFO] Step 45_300: discriminator_loss=0.580375, adversarial_loss=0.826070
# [INFO] Step 45_400: discriminator_loss=0.610928, adversarial_loss=0.929840
# [INFO] Step 45_500: discriminator_loss=0.637123, adversarial_loss=0.624238
# [INFO] Step 45_545: discriminator_loss=0.579059, adversarial_loss=1.226036
# [INFO] starting epoch 46 of 50...
# [INFO] Step 46_0: discriminator_loss=0.595376, adversarial_loss=0.792535
# [INFO] Step 46_100: discriminator_loss=0.551989, adversarial_loss=1.169351
# [INFO] Step 46_200: discriminator_loss=0.548375, adversarial_loss=0.901102
# [INFO] Step 46_300: discriminator_loss=0.549445, adversarial_loss=0.828330
# [INFO] Step 46_400: discriminator_loss=0.577074, adversarial_loss=0.720759
# [INFO] Step 46_500: discriminator_loss=0.593497, adversarial_loss=0.717546
# [INFO] Step 46_545: discriminator_loss=0.546650, adversarial_loss=0.940835
# [INFO] starting epoch 47 of 50...
# [INFO] Step 47_0: discriminator_loss=0.587131, adversarial_loss=1.053170
# [INFO] Step 47_100: discriminator_loss=0.562589, adversarial_loss=1.024979
# [INFO] Step 47_200: discriminator_loss=0.534885, adversarial_loss=0.958561
# [INFO] Step 47_300: discriminator_loss=0.575910, adversarial_loss=1.086204
# [INFO] Step 47_400: discriminator_loss=0.656148, adversarial_loss=0.520806
# [INFO] Step 47_500: discriminator_loss=0.601478, adversarial_loss=0.775045
# [INFO] Step 47_545: discriminator_loss=0.595692, adversarial_loss=0.715007
# [INFO] starting epoch 48 of 50...
# [INFO] Step 48_0: discriminator_loss=0.599259, adversarial_loss=1.153494
# [INFO] Step 48_100: discriminator_loss=0.569588, adversarial_loss=1.229121
# [INFO] Step 48_200: discriminator_loss=0.541905, adversarial_loss=0.915053
# [INFO] Step 48_300: discriminator_loss=0.577292, adversarial_loss=1.070953
# [INFO] Step 48_400: discriminator_loss=0.587112, adversarial_loss=0.858253
# [INFO] Step 48_500: discriminator_loss=0.586307, adversarial_loss=0.782826
# [INFO] Step 48_545: discriminator_loss=0.614808, adversarial_loss=0.872132
# [INFO] starting epoch 49 of 50...
# [INFO] Step 49_0: discriminator_loss=0.558601, adversarial_loss=1.029141
# [INFO] Step 49_100: discriminator_loss=0.597047, adversarial_loss=1.441361
# [INFO] Step 49_200: discriminator_loss=0.557157, adversarial_loss=1.132339
# [INFO] Step 49_300: discriminator_loss=0.557701, adversarial_loss=1.112458
# [INFO] Step 49_400: discriminator_loss=0.592419, adversarial_loss=0.772281
# [INFO] Step 49_500: discriminator_loss=0.586970, adversarial_loss=0.852131
# [INFO] Step 49_545: discriminator_loss=0.573975, adversarial_loss=1.151993
# [INFO] starting epoch 50 of 50...
# [INFO] Step 50_0: discriminator_loss=0.560849, adversarial_loss=0.873763
# [INFO] Step 50_100: discriminator_loss=0.576460, adversarial_loss=1.230889
# [INFO] Step 50_200: discriminator_loss=0.535341, adversarial_loss=1.017489
# [INFO] Step 50_300: discriminator_loss=0.577214, adversarial_loss=1.102328
# [INFO] Step 50_400: discriminator_loss=0.631864, adversarial_loss=0.735806
# [INFO] Step 50_500: discriminator_loss=0.647243, adversarial_loss=0.547489
# [INFO] Step 50_545: discriminator_loss=0.595109, adversarial_loss=1.301217
